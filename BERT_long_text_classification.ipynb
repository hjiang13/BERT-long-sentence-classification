# %% [markdown]
# <a href="https://colab.research.google.com/github/hjiang13/BERT-long-sentence-classification/blob/master/BERT_long_text_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install cleantext
# !pip install scikit-learn
# !pip install torch
# !pip install transformers
# !pip install matplotlib
# !pip install mlxtend
# !pip install seaborn
# !pip install Unidecode
# !pip install nltk
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 26.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 42.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 29.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 625.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.3 MB/s eta 0:00:00
# ...

# %%
ls
# Out:
# dataset/                                          LICENSE                     training_plmc.py
# images/                                           models/                     training_robert.py
# launch-experiments-20newsgroups.sh*               preprocess_20newsgroups.py  utils/
# launch-hierarchical-experiments-20newsgroups.sh*  README.md

# %%
# !git clone https://github.com/hjiang13/BERT-long-sentence-classification.git
# Out:
# Cloning into 'BERT-long-sentence-classification'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 49 (delta 17), reused 37 (delta 11), pack-reused 0
# Receiving objects: 100% (49/49), 40.39 KiB | 1.62 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
import os
os.chdir('BERT-long-sentence-classification/')

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), 1.00 KiB | 513.00 KiB/s, done.
# From https://github.com/hjiang13/BERT-long-sentence-classification
#    393064c..5a8f6a9  master     -> origin/master
# Updating 393064c..5a8f6a9
# Fast-forward
#  dataset/preprocess.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
# !chmod u+x ./launch-experiments-20newsgroups.sh
# !./launch-experiments-20newsgroups.sh True
# Out:
# Streaming output truncated to the last 5000 lines.
# 20news-bydate-train/rec.sport.hockey/53913
# 20news-bydate-train/rec.sport.hockey/53892
# 20news-bydate-train/rec.sport.hockey/53893
# 20news-bydate-train/rec.sport.hockey/53908
# 20news-bydate-train/rec.sport.hockey/53903
# 20news-bydate-train/rec.sport.hockey/53904
# 20news-bydate-train/rec.sport.hockey/53912
# 20news-bydate-train/rec.sport.hockey/53915
# 20news-bydate-train/rec.sport.hockey/53905
# 20news-bydate-train/rec.sport.hockey/53906
# 20news-bydate-train/rec.sport.hockey/53907
# 20news-bydate-train/rec.sport.hockey/53914
# 20news-bydate-train/rec.sport.hockey/54071
# 20news-bydate-train/rec.sport.hockey/53920
# 20news-bydate-train/rec.sport.hockey/54076
# 20news-bydate-train/rec.sport.hockey/54070
# 20news-bydate-train/rec.sport.hockey/54079
# 20news-bydate-train/rec.sport.hockey/54080
# 20news-bydate-train/rec.sport.hockey/53928
# 20news-bydate-train/sci.crypt/
# 20news-bydate-train/sci.crypt/14147
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True
